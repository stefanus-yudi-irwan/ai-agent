# %%
# !pip3 install -U openai openai-agents
# Out:
# Requirement already satisfied: openai in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (2.37.0)
# Requirement already satisfied: openai-agents in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (0.17.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from openai) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from openai) (2.13.4)
# Requirement already satisfied: sniffio in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.15)
# Requirement already satisfied: certifi in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: griffelib<3,>=2 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from openai-agents) (2.0.2)
# Requirement already satisfied: mcp<2,>=1.19.0 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from openai-agents) (1.27.1)
# Requirement already satisfied: requests<3,>=2.0 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from openai-agents) (2.34.2)
# Requirement already satisfied: types-requests<3,>=2.0 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from openai-agents) (2.33.0.20260518)
# Requirement already satisfied: websockets<17,>=15.0 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from openai-agents) (16.0)
# Requirement already satisfied: httpx-sse>=0.4 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from mcp<2,>=1.19.0->openai-agents) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from mcp<2,>=1.19.0->openai-agents) (4.26.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from mcp<2,>=1.19.0->openai-agents) (2.14.1)
# Requirement already satisfied: pyjwt>=2.10.1 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.19.0->openai-agents) (2.12.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from mcp<2,>=1.19.0->openai-agents) (0.0.29)
# Requirement already satisfied: sse-starlette>=1.6.1 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from mcp<2,>=1.19.0->openai-agents) (3.4.4)
# Requirement already satisfied: starlette>=0.27 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from mcp<2,>=1.19.0->openai-agents) (1.0.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from mcp<2,>=1.19.0->openai-agents) (0.47.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from requests<3,>=2.0->openai-agents) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from requests<3,>=2.0->openai-agents) (2.7.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.19.0->openai-agents) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.19.0->openai-agents) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.19.0->openai-agents) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.19.0->openai-agents) (0.30.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-settings>=2.5.2->mcp<2,>=1.19.0->openai-agents) (1.2.2)
# Requirement already satisfied: cryptography>=3.4.0 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.19.0->openai-agents) (48.0.0)
# Requirement already satisfied: cffi>=2.0.0 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.19.0->openai-agents) (2.0.0)
# Requirement already satisfied: pycparser in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.19.0->openai-agents) (3.0)
# Requirement already satisfied: click>=7.0 in /home/st_yudi/programs/anaconda3/envs/py311/lib/python3.11/site-packages (from uvicorn>=0.31.1->mcp<2,>=1.19.0->openai-agents) (8.4.0)

# %%
import os
from dotenv import load_dotenv
from agents import Agent, Runner, trace

load_dotenv(override=True)

agent = Agent(name="Jokester", instructions="You are a joke teller", model="gpt-4o-mini")
with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# Why did the autonomous AI agent bring a ladder to work?
#
# Because it wanted to take its performance to the next level!
# OPENAI_API_KEY is not set, skipping trace export

# %%
import os
print(os.getenv("OPENAI_API_KEY"))
# Out:
# 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

# %%
import agents
import openai

print(agents.__version__)
# Out:
# 0.17.3
