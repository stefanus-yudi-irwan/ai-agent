# %%
TAVILY_API_KEY = "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"
TAVILY_ACCOUNT = "default"

client = TavilyClient(TAVILY_API_KEY)
response = client.search(
    query="What are the latest update in NVIDIA?",
    search_depth="basic",
)
print(response)
# Out:
# {'query': 'What are the latest update in NVIDIA?', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.nvidia.com/en-us/software/nvidia-app/release-highlights', 'title': 'Updates and Release Highlights | NVIDIA', 'content': "+ The latest NVIDIA Broadcast release features two new effects – the new Studio Voice, which upgrades your mic to deliver premium audio quality, and Virtual Keylight, which automatically relights your face for even lighting throughout your livestreams. Eye contact and background noise removal get a quality improvement, plus an updated user interface lets users combine even more effects. Download NVIDIA Broadcast from the Discover section on the Home tab.\n NVIDIA Smooth Motion [...] ## \n\nWhat's new in NVIDIA App 11.0.3.241\n\nNew Updates\n\n DLSS Override Support for The Elder Scrolls IV: Oblivion Remastered\n  + Enable DLSS Multi Frame Generation on your GeForce RTX 50 Series GPU with the DLSS Override feature. All RTX G
# ...

# %%
response
# Out:
# {'query': 'What are the latest update in NVIDIA?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.nvidia.com/en-us/software/nvidia-app/release-highlights',
#    'title': 'Updates and Release Highlights | NVIDIA',
# ...
